# %% [markdown]
# # Joining the 2022 approved drugs
# This notebook has the objective of concatenating the FDA approved small-molecule drugs of 2022 (updating our dataset);

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, PandasTools
from rdkit.Chem.SaltRemover import SaltRemover
import pandas as pd
import session_info

# %%
# This is the dataset without the 2022 drugs
drugs_db_route_merged = pd.read_csv('../data/approved_drugs_final.csv')
drugs_db_route_merged = drugs_db_route_merged.drop(["ROMol","Mol_Clean","mw", "n_hba", "n_hbd", "logp"], axis=1)
drugs_db_route_merged
# Out:
#                  active_ingredient_moiety nda_bla  approval_year  \
# 0                            troglitazone     NDA           1997
# 1                               imiquimod     NDA           1997
# 2                anagrelide hydrochloride     NDA           1997
# 3                     nelfinavir mesylate     NDA           1997
# 4                    delavirdine mesylate     NDA           1997
# ..                                    ...     ...            ...
# 544                  gadoterate meglumine     NDA           2013
# 545                     dimethyl fumarate     NDA           2013
# 546                           dalbavancin     NDA           2014
# 547                   tafamidis meglumine     NDA           2019
# 548  Brilliant Blue G Ophthalmic Solution     NDA           2019
#
#                                    active DrugBank ID  \
# 0                            troglitazone     DB00197
# 1                               imiquimod     DB00724
# 2                              anagrelide     DB00261
# 3                              nelfinavir     DB00220
# 4                             delavirdine     DB00705
# ..                                    ...         ...
# 544                  gadoterate meglumine     DB09132
# 545                     dimethyl fumarate     DB08908
# 546                           dalbavancin     DB06219
# 547                   tafamidis meglumine     DB11644
# 548  Brilliant Blue G Ophthalmic Solution     DB15594
#
#                               Drug Groups  \
# 0    approved; investigational; withdrawn
# 1               approved; investigational
# 2                                approved
# 3                                approved
# 4                                approved
# ..                                    ...
# 544                              approved
# 545             approved; investigational
# 546             approved; investigational
# 547             approved; investigational
# 548                              approved
#
#                                                 SMILES               Name  \
# 0    CC1=C(C)C2=C(CCC(C)(COC3=CC=C(CC4SC(=O)NC4=O)C...       Troglitazone
# 1                   CC(C)CN1C=NC2=C1C1=C(C=CC=C1)N=C2N          Imiquimod
# 2                      ClC1=CC=C2N=C3NC(=O)CN3CC2=C1Cl         Anagrelide
# 3    [H][C@@]12CCCC[C@]1([H])CN(C[C@@H](O)[C@H](CSC...         Nelfinavir
# 4    CC(C)NC1=C(N=CC=C1)N1CCN(CC1)C(=O)C1=CC2=C(N1)...        Delavirdine
# ..                                                 ...                ...
# 544  [Gd+3].CNC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO....     Gadoteric acid
# 545                      [H]\C(=C(\[H])C(=O)OC)C(=O)OC  Dimethyl fumarate
# 546  CN[C@H]1C(=O)N[C@@H]2Cc3ccc(Oc4cc5cc(Oc6ccc(cc...        Dalbavancin
# 547       OC(=O)C1=CC=C2N=C(OC2=C1)C1=CC(Cl)=CC(Cl)=C1          Tafamidis
# 548  [Na+].CCOC1=CC=C(NC2=CC=C(C=C2)C(=C2\C=C/C(/C=...   Brilliant blue G
#
#              Drug Type        route
# 0    SmallMoleculeDrug         oral
# 1    SmallMoleculeDrug      topical
# 2    SmallMoleculeDrug         oral
# 3    SmallMoleculeDrug         oral
# 4    SmallMoleculeDrug         oral
# ..                 ...          ...
# 544  SmallMoleculeDrug  intravenous
# 545  SmallMoleculeDrug         oral
# 546  SmallMoleculeDrug  intravenous
# 547  SmallMoleculeDrug         oral
# 548  SmallMoleculeDrug   ophthalmic
#
# [549 rows x 10 columns]

# %%
# Loading the approved drugs from 2022, retrived from the same sources
# The SMILES were added manually and we generated a csv file afterwards
drugs_2022 = pd.read_csv("../data/drugs_2022.csv")
drugs_2022
# Out:
#    active_ingredient_moiety nda_bla  approval_year           active  \
# 0              daridorexant     NDA           2022     daridorexant
# 1               abrocitinib     NDA           2022      abrocitinib
# 2                 mitapivat     NDA           2022        mitapivat
# 3                pacritinib     NDA           2022       pacritinib
# 4                ganaxolone     NDA           2022       ganaxolone
# 5             oteseconazole     NDA           2022    oteseconazole
# 6                mavacamten     NDA           2022       mavacamten
# 7                 tapinarof     NDA           2022        tapinarof
# 8           deucravacitinib     NDA           2022  deucravacitinib
# 9                omidenepag     NDA           2022       omidenepag
# 10              futibatinib     NDA           2022      futibatinib
# 11             olutasidenib     NDA           2022     olutasidenib
# 12                adagrasib     NDA           2022        adagrasib
# 13              lenacapavir     NDA           2022      lenacapavir
#
#    DrugBank ID Drug Groups                                             SMILES  \
# 0      DB15031    approved  COC1=CC(C(=O)N2CCC[C@@]2(C)C2=NC3=C(N2)C=CC(Cl...
# 1      DB14973    approved  CCCS(=O)(=O)N[C@H]1C[C@H](C1)N(C)C1=C2C=CNC2=N...
# 2      DB16236    approved  O=C(N1CCN(CC2CC2)CC1)C1=CC=C(NS(=O)(=O)C2=CC=C...
# 3      DB11697    approved  C(CN1CCCC1)OC1=CC=C2NC3=NC=CC(=N3)C3=CC(COC\C=...
# 4      DB05087    approved  [H][C@@]12CC[C@H](C(C)=O)[C@@]1(C)CC[C@@]1([H]...
# 5      DB13055    approved  O[C@@](CN1C=NN=N1)(C1=CC=C(F)C=C1F)C(F)(F)C1=C...
# 6      DB14921    approved        CC(C)N1C(=O)NC(N[C@@H](C)C2=CC=CC=C2)=CC1=O
# 7      DB06083    approved             CC(C)C1=C(O)C=C(\C=C\C2=CC=CC=C2)C=C1O
# 8      DB16650    approved  [2H]C([2H])([2H])NC(=O)C1=C(NC2=CC=CC(C3=NN(C)...
# 9      DB15071    approved  CC(C)OC(=O)CNC1=CC=CC(CN(CC2=CC=C(C=C2)N2C=CC=...
# 10     DB15149    approved  COC1=CC(=CC(OC)=C1)C#CC1=NN([C@H]2CCN(C2)C(=O)...
# 11     DB16267    approved  C[C@H](NC1=CC=C(C#N)N(C)C1=O)C1=CC2=C(NC1=O)C=...
# 12     DB15568    approved  [H][C@@]1(COC2=NC3=C(CCN(C3)C3=CC=CC4=C3C(Cl)=...
# 13     DB15673    approved  [H][C@]12C[C@@]1([H])C(F)(F)C1=C2C(=NN1CC(=O)N...
#
#                Name          Drug Type         route
# 0      Daridorexant  SmallMoleculeDrug          oral
# 1       Abrocitinib  SmallMoleculeDrug          oral
# 2         Mitapivat  SmallMoleculeDrug          oral
# 3        Pacritinib  SmallMoleculeDrug          oral
# 4        Ganaxolone  SmallMoleculeDrug          oral
# 5     Oteseconazole  SmallMoleculeDrug          oral
# 6        Mavacamten  SmallMoleculeDrug          oral
# 7         Tapinarof  SmallMoleculeDrug       topical
# 8   Deucravacitinib  SmallMoleculeDrug          oral
# 9        Omidenepag  SmallMoleculeDrug    ophthalmic
# 10      Futibatinib  SmallMoleculeDrug          oral
# 11     Olutasidenib  SmallMoleculeDrug          oral
# 12        Adagrasib  SmallMoleculeDrug          oral
# 13      Lenacapavir  SmallMoleculeDrug  subcutaneous

# %% [markdown]
# ## Merging the two datasets

# %%
concat_object = [drugs_db_route_merged, drugs_2022]
drugs_final = pd.concat(concat_object, ignore_index=True, axis=0)
drugs_final
# Out:
#      active_ingredient_moiety nda_bla  approval_year        active  \
# 0                troglitazone     NDA           1997  troglitazone
# 1                   imiquimod     NDA           1997     imiquimod
# 2    anagrelide hydrochloride     NDA           1997    anagrelide
# 3         nelfinavir mesylate     NDA           1997    nelfinavir
# 4        delavirdine mesylate     NDA           1997   delavirdine
# ..                        ...     ...            ...           ...
# 558                omidenepag     NDA           2022    omidenepag
# 559               futibatinib     NDA           2022   futibatinib
# 560              olutasidenib     NDA           2022  olutasidenib
# 561                 adagrasib     NDA           2022     adagrasib
# 562               lenacapavir     NDA           2022   lenacapavir
#
#     DrugBank ID                           Drug Groups  \
# 0       DB00197  approved; investigational; withdrawn
# 1       DB00724             approved; investigational
# 2       DB00261                              approved
# 3       DB00220                              approved
# 4       DB00705                              approved
# ..          ...                                   ...
# 558     DB15071                              approved
# 559     DB15149                              approved
# 560     DB16267                              approved
# 561     DB15568                              approved
# 562     DB15673                              approved
#
#                                                 SMILES          Name  \
# 0    CC1=C(C)C2=C(CCC(C)(COC3=CC=C(CC4SC(=O)NC4=O)C...  Troglitazone
# 1                   CC(C)CN1C=NC2=C1C1=C(C=CC=C1)N=C2N     Imiquimod
# 2                      ClC1=CC=C2N=C3NC(=O)CN3CC2=C1Cl    Anagrelide
# 3    [H][C@@]12CCCC[C@]1([H])CN(C[C@@H](O)[C@H](CSC...    Nelfinavir
# 4    CC(C)NC1=C(N=CC=C1)N1CCN(CC1)C(=O)C1=CC2=C(N1)...   Delavirdine
# ..                                                 ...           ...
# 558  CC(C)OC(=O)CNC1=CC=CC(CN(CC2=CC=C(C=C2)N2C=CC=...    Omidenepag
# 559  COC1=CC(=CC(OC)=C1)C#CC1=NN([C@H]2CCN(C2)C(=O)...   Futibatinib
# 560  C[C@H](NC1=CC=C(C#N)N(C)C1=O)C1=CC2=C(NC1=O)C=...  Olutasidenib
# 561  [H][C@@]1(COC2=NC3=C(CCN(C3)C3=CC=CC4=C3C(Cl)=...     Adagrasib
# 562  [H][C@]12C[C@@]1([H])C(F)(F)C1=C2C(=NN1CC(=O)N...   Lenacapavir
#
#              Drug Type         route
# 0    SmallMoleculeDrug          oral
# 1    SmallMoleculeDrug       topical
# 2    SmallMoleculeDrug          oral
# 3    SmallMoleculeDrug          oral
# 4    SmallMoleculeDrug          oral
# ..                 ...           ...
# 558  SmallMoleculeDrug    ophthalmic
# 559  SmallMoleculeDrug          oral
# 560  SmallMoleculeDrug          oral
# 561  SmallMoleculeDrug          oral
# 562  SmallMoleculeDrug  subcutaneous
#
# [563 rows x 10 columns]

# %% [markdown]
# ## Cleaning (again)

# %%
# RDKit function to create "ROMol", not cleaned yet
PandasTools.AddMoleculeColumnToFrame(drugs_final, "SMILES")

# %%
# Functions to clean the data

# defining the salts we want to remove from the database
remover = SaltRemover(defnData="[Cl,Br,Na,K,Gd]")

# Defining the function to neutralize the atoms in organic molecules
def neutralize_atoms(mol):
    pattern = Chem.MolFromSmarts("[+1!h0!$([*]~[-1,-2,-3,-4]),-1!$([*]~[+1,+2,+3,+4])]")
    at_matches = mol.GetSubstructMatches(pattern)
    at_matches_list = [y[0] for y in at_matches]
    if len(at_matches_list) > 0:
        for at_idx in at_matches_list:
            atom = mol.GetAtomWithIdx(at_idx)
            chg = atom.GetFormalCharge()
            hcount = atom.GetTotalNumHs()
            atom.SetFormalCharge(0)
            atom.SetNumExplicitHs(hcount - chg)
            atom.UpdatePropertyCache()
    return mol

# %%
mols = [] # creating an empty list
## FUNCTION FOR CHECKING THE NON READABLE:
# Creating a loop to 1) convert from smiles to mol and use the `remover.StripMol() on each structure
for i, smi in enumerate(drugs_final.SMILES):
    try:
        mol = Chem.MolFromSmiles(smi) # converting to a proper format
        mol = remover.StripMol(mol) # stripping the salts
        mols.append(mol) # appending to a list
    except:
        print(smi,i) # printing the exceptions, or the non-readable smiles and the respective index

# %%
# Running the same function again (it's better to define a function and just call it again...)
mols = []
for i, smi in enumerate(drugs_final.SMILES):
    try:
        mol = Chem.MolFromSmiles(smi)
        mol = remover.StripMol(neutralize_atoms(mol))
        mols.append(mol)
    except:
        print(smi,i)

# %%
# Applying the functions created before

# Removing the salts
drugs_final["Mol_Clean"] = drugs_final.ROMol.apply(remover.StripMol)
# neutralizing atoms O- goes to OH and so on..
drugs_final["Mol_Clean"] = drugs_final.Mol_Clean.apply(neutralize_atoms)

# %% [markdown]
# ### Generating descriptors

# %%
drugs_final["mw"] = drugs_final["Mol_Clean"].apply(Descriptors.ExactMolWt)
drugs_final["n_hba"] = drugs_final["Mol_Clean"].apply(Descriptors.NumHAcceptors)
drugs_final["n_hbd"] = drugs_final["Mol_Clean"].apply(Descriptors.NumHDonors)
drugs_final["logp"] = drugs_final["Mol_Clean"].apply(Descriptors.MolLogP)

# %% [markdown]
# ## Saving the file

# %%
drugs_final = drugs_final.drop(['ROMol', 'Mol_Clean'], axis=1)
drugs_final
# Out:
#      active_ingredient_moiety nda_bla  approval_year        active  \
# 0                troglitazone     NDA           1997  troglitazone
# 1                   imiquimod     NDA           1997     imiquimod
# 2    anagrelide hydrochloride     NDA           1997    anagrelide
# 3         nelfinavir mesylate     NDA           1997    nelfinavir
# 4        delavirdine mesylate     NDA           1997   delavirdine
# ..                        ...     ...            ...           ...
# 558                omidenepag     NDA           2022    omidenepag
# 559               futibatinib     NDA           2022   futibatinib
# 560              olutasidenib     NDA           2022  olutasidenib
# 561                 adagrasib     NDA           2022     adagrasib
# 562               lenacapavir     NDA           2022   lenacapavir
#
#     DrugBank ID                           Drug Groups  \
# 0       DB00197  approved; investigational; withdrawn
# 1       DB00724             approved; investigational
# 2       DB00261                              approved
# 3       DB00220                              approved
# 4       DB00705                              approved
# ..          ...                                   ...
# 558     DB15071                              approved
# 559     DB15149                              approved
# 560     DB16267                              approved
# 561     DB15568                              approved
# 562     DB15673                              approved
#
#                                                 SMILES          Name  \
# 0    CC1=C(C)C2=C(CCC(C)(COC3=CC=C(CC4SC(=O)NC4=O)C...  Troglitazone
# 1                   CC(C)CN1C=NC2=C1C1=C(C=CC=C1)N=C2N     Imiquimod
# 2                      ClC1=CC=C2N=C3NC(=O)CN3CC2=C1Cl    Anagrelide
# 3    [H][C@@]12CCCC[C@]1([H])CN(C[C@@H](O)[C@H](CSC...    Nelfinavir
# 4    CC(C)NC1=C(N=CC=C1)N1CCN(CC1)C(=O)C1=CC2=C(N1)...   Delavirdine
# ..                                                 ...           ...
# 558  CC(C)OC(=O)CNC1=CC=CC(CN(CC2=CC=C(C=C2)N2C=CC=...    Omidenepag
# 559  COC1=CC(=CC(OC)=C1)C#CC1=NN([C@H]2CCN(C2)C(=O)...   Futibatinib
# 560  C[C@H](NC1=CC=C(C#N)N(C)C1=O)C1=CC2=C(NC1=O)C=...  Olutasidenib
# 561  [H][C@@]1(COC2=NC3=C(CCN(C3)C3=CC=CC4=C3C(Cl)=...     Adagrasib
# 562  [H][C@]12C[C@@]1([H])C(F)(F)C1=C2C(=NN1CC(=O)N...   Lenacapavir
#
#              Drug Type         route          mw  n_hba  n_hbd     logp
# 0    SmallMoleculeDrug          oral  441.160994      6      2  4.37426
# 1    SmallMoleculeDrug       topical  240.137497      4      1  2.82270
# 2    SmallMoleculeDrug          oral  254.996617      3      1  1.92630
# 3    SmallMoleculeDrug          oral  567.313078      6      4  4.74762
# 4    SmallMoleculeDrug          oral  456.194360      6      3  2.71710
# ..                 ...           ...         ...    ...    ...      ...
# 558  SmallMoleculeDrug    ophthalmic  520.189274      9      1  3.41690
# 559  SmallMoleculeDrug          oral  418.175339      8      1  1.78490
# 560  SmallMoleculeDrug          oral  354.088353      5      2  2.92498
# 561  SmallMoleculeDrug          oral  603.252479      8      0  4.73298
# 562  SmallMoleculeDrug  subcutaneous  967.143519     10      2  7.66280
#
# [563 rows x 14 columns]

# %%
drugs_final.to_csv("../data/approved_drugs_final_2022.csv", index=False)

# %%
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# pandas              1.5.3
# rdkit               2021.09.5
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 9.4.0
# asttokens           NA
# backcall            0.2.0
# cffi                1.15.1
# colorama            0.4.6
# comm                0.1.3
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.6
# decorator           5.1.1
# defusedxml          0.7.1
# executing           1.2.0
# google              NA
# importlib_metadata  NA
# ipykernel           6.22.0
# ipython_genutils    0.2.0
# ipywidgets          7.7.3
# jedi                0.18.2
# jupyter_server      2.5.0
# mpl_toolkits        NA
# numexpr             2.8.3
# numpy               1.23.5
# packaging           23.0
# parso               0.8.3
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# platformdirs        3.2.0
# prompt_toolkit      3.0.38
# psutil              5.9.4
# ptyprocess          0.7.0
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.14.0
# pytz                2023.3
# six                 1.16.0
# stack_data          0.6.2
# tornado             6.2
# traitlets           5.9.0
# typing_extensions   NA
# wcwidth             0.2.6
# zipp                NA
# zmq                 25.0.2
# zope                NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             8.12.0
# jupyter_client      8.1.0
# jupyter_core        5.3.0
# jupyterlab          3.5.2
# notebook            6.5.3
# -----
# Python 3.8.16 | packaged by conda-forge | (default, Feb  1 2023, 16:01:55) [GCC 11.3.0]
# Linux-6.2.11-arch1-1-x86_64-with-glibc2.10
# -----
# Session information updated at 2023-04-19 17:04
# </pre>
# </details>
